# %%
import numpy as np
import fipy
import matplotlib.pyplot as plt

# %%
from fipy import Grid1D, CellVariable
from fipy import TransientTerm, DiffusionTerm

# %%
# parameters
## physics
L = 1.0
U_H = 1.0
U_L = 0
alpha = 1.0
## FVM
N = 40
dt = 0.005
Nt = 100

# %%
# define grid
dx = L/N
msh = Grid1D(dx=dx, nx=N)

# %%
xcc = msh.cellCenters.value[0]

# %%
# define cell variables
u = CellVariable(mesh = msh, value = 0.0)

# %%
# set BC
# NO FLUX DEFAULT
pass

# %%
uval = u.value

# %%
plt.plot(xcc, uval,'o')
plt.ylabel('u at cell center')
plt.xlabel('x of cell center')
# Out:
# Text(0.5, 0, 'x of cell center')

# %%
# set IC
uval[xcc < L/2] = U_H
uval[xcc >= L/2] = U_L

# %%
plt.plot(xcc, uval,'o')
plt.ylabel('u at cell center')
plt.xlabel('x of cell center')
# Out:
# Text(0.5, 0, 'x of cell center')

# %%
np.sum(uval * dx)
# Out:
# 0.5

# %%
# define PDE
eqn = TransientTerm(var = u) == DiffusionTerm(var = u, coeff = alpha)

# %%
# SOLVE and sample the solution
u00 = np.zeros(Nt)
for n in range(Nt):
    u00[n] = uval[0]
    if n%10 == 0:
        plt.plot(xcc, uval)
    eqn.solve(dt=dt)
plt.xlabel('x')
plt.ylabel('u')
# Out:
# Text(0, 0.5, 'u')

# %%
plt.plot(np.arange(Nt)*dt, u00)
plt.ylabel('u at center of leftmost cell')
plt.xlabel('t')
# Out:
# Text(0.5, 0, 't')
