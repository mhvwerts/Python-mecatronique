# %%
import numpy as np
import fipy
import matplotlib.pyplot as plt

# %%
from fipy import Grid1D, CellVariable
from fipy import TransientTerm, DiffusionTerm

# %%
# parameters
## physics
L = 1.0
U_H = 1.0
U_L = 0
alphaL = 1.0
alphaR = 0.2
## FVM
N = 500
dt = 0.001
Nt = 500

# %%
# define grid
dx = L/N
msh = Grid1D(dx=dx, nx=N)

# %%
xcc = msh.cellCenters.value[0]

# %%
# define cell variables
u = CellVariable(mesh = msh, value = 0.0)
uval = u.value

# %%
alpha = CellVariable(mesh = msh, value = 0.0)
alphaval = alpha.value

# %%
# set BC
pass
u.constrain(value = U_H, where = msh.facesLeft)
u.constrain(value = U_L, where = msh.facesRight)

# %%
# set alpha
alphaval[xcc < L/2] = alphaL
alphaval[xcc >= L/2] = alphaR

# %%
plt.plot(xcc, alphaval,'o')
plt.ylim(0,1.1)
plt.xlabel('x')
plt.ylabel('alpha')
# Out:
# Text(0, 0.5, 'alpha')

# %%
# set IC
uval[xcc < L/2] = U_H
uval[xcc >= L/2] = U_L

# %%
plt.plot(xcc, uval,'o')
plt.xlabel('x')
plt.ylabel('u')
# Out:
# Text(0, 0.5, 'u')

# %%
np.sum(uval * dx)
# Out:
# 0.5000000000000002

# %%
# define PDE
eqn = TransientTerm(var = u) == DiffusionTerm(var = u, coeff = alpha)

# %%
# SOLVE and sample the solution
for n in range(Nt):
    if n%50 == 0:
        plt.plot(xcc, uval)
    eqn.solve(dt=dt)
plt.xlabel('x')
plt.ylabel('u')
# Out:
# Text(0, 0.5, 'u')
